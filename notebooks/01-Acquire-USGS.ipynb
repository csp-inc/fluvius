# %%
import sys
sys.path.append('/content')
from src.fluvius import USGS_Water_DB, USGS_Station

# %load_ext autoreload
# %autoreload 2

db = USGS_Water_DB()
db.get_station_df()
db.station_df.to_csv('/content/data/station_metadata.csv', index=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# There is no [linux64] chromedriver for browser 90.0.4430 in cache
# Get LATEST driver version for 90.0.4430
# Trying to download new driver from https://chromedriver.storage.googleapis.com/90.0.4430.24/chromedriver_linux64.zip
# Driver has been saved in cache [/root/.wdm/drivers/chromedriver/linux64/90.0.4430.24]

# %%
db.station_df
# Out:
#              site_no                                          site_name  \
# 0           01472157                 French Creek near Phoenixville, PA
# 1           01478245           White Clay Creek near Strickersville, PA
# 2           01480617         West Branch Brandywine Creek at Modena, PA
# 3           01480870  East Branch Brandywine Creek below Downingtown...
# 4           01481000                Brandywine Creek at Chadds Ford, PA
# ..               ...                                                ...
# 160  393806095273700               Atchison County Lake near Horton, KS
# 161  393817095260100        Clear Creek at Decator Road near Horton, KS
# 162  394126096073500  Black Vermillion River Tributary above Central...
# 163  394146096085500                  Centralia Lake near Centralia, KS
# 164  394218096095000  Black Vermillion River Tributary below Central...
#
#      Latitude  Longitude                    geometry
# 0     40.1515   -75.6013  POINT (-75.60130 40.15150)
# 1     39.7475   -75.7708  POINT (-75.77080 39.74750)
# 2     39.9618   -75.8013  POINT (-75.80130 39.96180)
# 3     39.9687   -75.6733  POINT (-75.67330 39.96870)
# 4     39.8698   -75.5933  POINT (-75.59330 39.86980)
# ..        ...        ...                         ...
# 160   39.6350   -95.4603  POINT (-95.46030 39.63500)
# 161   39.6381   -95.4336  POINT (-95.43360 39.63810)
# 162   39.6906   -96.1264  POINT (-96.12640 39.69060)
# 163   39.6961   -96.1486  POINT (-96.14860 39.69610)
# 164   39.7050   -96.1639  POINT (-96.16390 39.70500)
#
# [165 rows x 5 columns]

# %%
d_list = []
for site_no in db.station_df.site_no: #full loop for all stations took 24 hours...
    #instantiate water data
    water_data = USGS_Station(site_no) 
    water_data.get_water_df()
    #we would likely append this data to the USGS_Water_DB dataframe?
    #especially if the csv is already collected, open it locally?
    d_list.append(water_data)
    #currently only 39 complete stations which is a problem...
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [/root/.wdm/drivers/chromedriver/linux64/90.0.4430.24/chromedriver] found in cache

# %%
d_list[5].df
# Out:
#              Date-Time Instantaneous computed discharge (cfs)  \
# 0     12/31/2014 23:00                                     38
# 1     12/31/2014 22:00                                     38
# 2     12/31/2014 21:00                                     38
# 3     12/31/2014 20:00                                     38
# 4     12/31/2014 19:00                                     38
# ...                ...                                    ...
# 8678  01/01/2020 05:00                                     22
# 8679  01/01/2020 04:00                                     22
# 8680  01/01/2020 03:00                                     22
# 8681  01/01/2020 02:00                                     22
# 8682  01/01/2020 01:00                                     22
#
#      Computed instantaneous suspended sediment (mg/L)  \
# 0                                                 2.5
# 1                                                 2.7
# 2                                                 2.7
# 3                                                 2.5
# 4                                                 2.5
# ...                                               ...
# 8678                                              3.2
# 8679                                              3.5
# 8680                                              3.2
# 8681                                              3.2
# 8682                                              3.5
#
#      Computed instantaneous suspended sediment, lower 90% prediction (mg/L)  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 8678                                                1.1
# 8679                                                1.2
# 8680                                                1.1
# 8681                                                1.1
# 8682                                                1.2
#
#      Computed instantaneous suspended sediment, upper 90% prediction (mg/L)  \
# 0                                                   7.2
# 1                                                   8.0
# 2                                                   8.0
# 3                                                   7.2
# 4                                                   7.2
# ...                                                 ...
# 8678                                                9.5
# 8679                                                 10
# 8680                                                9.5
# 8681                                                9.5
# 8682                                                 10
#
#      Instantaneous turbidity (FNU)
# 0                             0.80
# 1                             0.90
# 2                             0.90
# 3                             0.80
# 4                             0.80
# ...                            ...
# 8678                           1.1
# 8679                           1.2
# 8680                           1.1
# 8681                           1.1
# 8682                           1.2
#
# [52603 rows x 6 columns]
