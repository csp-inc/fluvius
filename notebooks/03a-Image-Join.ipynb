# %% [markdown]
# ## Accessing Sentinel-2 L2A data with the Planetary Computer STAC API
#
# The [Planetary Computer Hub](https://planetarycomputer.microsoft.com/compute) is pre-configured to use your API key.

# %%
### Environment setup
from pystac_client import Client
import planetary_computer as pc
import os

# Set the environment variable PC_SDK_SUBSCRIPTION_KEY, or set it here.
# The Hub sets PC_SDK_SUBSCRIPTION_KEY automatically.
# pc.settings.set_subscription_key(<YOUR API Key>)
env_vars = !cat /content/.env

for var in env_vars:
    key, value = var.split(' = ')
    os.environ[key] = value

# %%
import fsspec
storage_options={'account_name':os.environ['ACCOUNT_NAME'],\
                 'account_key':os.environ['BLOB_KEY']}

# %%
fs = fsspec.filesystem('az', account_name=storage_options['account_name'], account_key=storage_options['account_key'])

# %%
dirc = 'hls_output_2021-05-13'
raw_tifs = fs.ls(f'fia/{dirc}')
# Out:
# ['fia/hls_output_2021-05-13/2016_10SDH.tif',
#  'fia/hls_output_2021-05-13/2016_10SDJ.tif',
#  'fia/hls_output_2021-05-13/2016_10SEF.tif',
#  'fia/hls_output_2021-05-13/2016_10SEG.tif',
#  'fia/hls_output_2021-05-13/2016_10SEH.tif',
#  'fia/hls_output_2021-05-13/2016_10SEJ.tif',
#  'fia/hls_output_2021-05-13/2016_10SFE.tif',
#  'fia/hls_output_2021-05-13/2016_10SFF.tif',
#  'fia/hls_output_2021-05-13/2016_10SFG.tif',
#  'fia/hls_output_2021-05-13/2016_10SFH.tif',
#  'fia/hls_output_2021-05-13/2016_10SFJ.tif',
#  'fia/hls_output_2021-05-13/2016_10SGD.tif',
#  'fia/hls_output_2021-05-13/2016_10SGE.tif',
#  'fia/hls_output_2021-05-13/2016_10SGF.tif',
#  'fia/hls_output_2021-05-13/2016_10SGG.tif',
#  'fia/hls_output_2021-05-13/2016_10SGH.tif',
#  'fia/hls_output_2021-05-13/2016_10SGJ.tif',
#  'fia/hls_output_2021-05-13/2016_10TCK.tif',
#  'fia/hls_output_2021-05-13/2016_10TCL.tif',
#  'fia/hls_output_2021-05-13/2016_10TCM.tif',
#  'fia/hls_output_2021-05-13/2016_10TCN.tif',
#  'fia/hls_output_2021-05-13/2016_10TCP.tif',
#  'fia/hls_output_2021-05-13/2016_10TCT.tif',
#  'fia/hls_output_2021-05-13/2016_10TDK.tif',
#  'fia/hls_output_2021-05-13/2016_10TDL.tif',
#  'fia/hls_output_2021-05-13/2016_10TDM.tif',
#  'fia/hls_output_2021-05-13/2016_10TDN.tif',
#  'fia/hls_output_2021-05-13/2016_10TDP.tif',
#  'fia/hls_output_2021-05-13/2016_10TDQ.tif',
#  'fia/hls_output_2021-05-13/2016_10TDR.tif',
#  'fia/hls_output_2021-05-13/2016_10TDS.tif',
#  'fia/hls_output_2021-05-13/2016_10TDT.tif',
#  'fia/hls_output_2021-05-13/2016_10TEK.tif',
#  'fia/hls_output_2021-05-13/2016_10TEL.tif',
#  'fia/hls_output_2021-05-13/2016_10TEM.tif',
#  'fia/hls_output_2021-05-13/2016_10TEN.tif',
#  'fia/hls_output_2021-05-13/2016_10TEP.tif',
#  'fia/hls_output_2021-05-13/2016_10TEQ.tif',
#  'fia/hls_output_2021-05-13/2016_10TER.tif',
#  'fia/hls_output_2021-05-13/2016_10TES.tif',
#  'fia/hls_output_2021-05-13/2016_10TET.tif',
#  'fia/hls_output_2021-05-13/2016_10TFK.tif',
#  'fia/hls_output_2021-05-13/2016_10TFL.tif',
#  'fia/hls_output_2021-05-13/2016_10TFM.tif',
#  'fia/hls_output_2021-05-13/2016_10TFN.tif',
#  'fia/hls_output_2021-05-13/2016_10TFP.tif',
#  'fia/hls_output_2021-05-13/2016_10TFQ.tif',
#  'fia/hls_output_2021-05-13/2016_10TFR.tif',
#  'fia/hls_output_2021-05-13/2016_10TFS.tif',
#  'fia/hls_output_2021-05-13/2016_10TFT.tif',
#  'fia/hls_output_2021-05-13/2016_10TGK.tif',
#  'fia/hls_output_2021-05-13/2016_10TGL.tif',
#  'fia/hls_output_2021-05-13/2016_10TGM.tif',
#  'fia/hls_output_2021-05-13/2016_10TGN.tif',
#  'fia/hls_output_2021-05-13/2016_10TGT.tif',
#  'fia/hls_output_2021-05-13/2016_10UCU.tif',
#  'fia/hls_output_2021-05-13/2016_10UDU.tif',
#  'fia/hls_output_2021-05-13/2016_10UDV.tif',
#  'fia/hls_output_2021-05-13/2016_10UEU.tif',
#  'fia/hls_output_2021-05-13/2016_10UEV.tif',
#  'fia/hls_output_2021-05-13/2016_10UFU.tif',
#  'fia/hls_output_2021-05-13/2016_10UFV.tif',
#  'fia/hls_output_2021-05-13/2016_10UGU.tif',
#  'fia/hls_output_2021-05-13/2016_10UGV.tif',
#  'fia/hls_output_2021-05-13/2016_11SKA.tif',
#  'fia/hls_output_2021-05-13/2016_11SKB.tif',
#  'fia/hls_output_2021-05-13/2016_11SKC.tif',
#  'fia/hls_output_2021-05-13/2016_11SKD.tif',
#  'fia/hls_output_2021-05-13/2016_11SKT.tif',
#  'fia/hls_output_2021-05-13/2016_11SKU.tif',
#  'fia/hls_output_2021-05-13/2016_11SKV.tif',
#  'fia/hls_output_2021-05-13/2016_11SLA.tif',
#  'fia/hls_output_2021-05-13/2016_11SLB.tif',
#  'fia/hls_output_2021-05-13/2016_11SLC.tif',
#  'fia/hls_output_2021-05-13/2016_11SLT.tif',
#  'fia/hls_output_2021-05-13/2016_11SLU.tif',
#  'fia/hls_output_2021-05-13/2016_11SLV.tif',
#  'fia/hls_output_2021-05-13/2016_11SMA.tif',
#  'fia/hls_output_2021-05-13/2016_11SMR.tif',
#  'fia/hls_output_2021-05-13/2016_11SMS.tif',
#  'fia/hls_output_2021-05-13/2016_11SMT.tif',
#  'fia/hls_output_2021-05-13/2016_11SMU.tif',
#  'fia/hls_output_2021-05-13/2016_11SMV.tif',
#  'fia/hls_output_2021-05-13/2016_11SNS.tif',
#  'fia/hls_output_2021-05-13/2016_11SNT.tif',
#  'fia/hls_output_2021-05-13/2016_11SNU.tif',
#  'fia/hls_output_2021-05-13/2016_11SPS.tif',
#  'fia/hls_output_2021-05-13/2016_11TKE.tif',
#  'fia/hls_output_2021-05-13/2016_11TKF.tif',
#  'fia/hls_output_2021-05-13/2016_11TKG.tif',
#  'fia/hls_output_2021-05-13/2016_11ULP.tif',
#  'fia/hls_output_2021-05-13/2016_11ULQ.tif',
#  'fia/hls_output_2021-05-13/2018_10SDH.tif',
#  'fia/hls_output_2021-05-13/2018_10SDJ.tif',
#  'fia/hls_output_2021-05-13/2018_10SEF.tif',
#  'fia/hls_output_2021-05-13/2018_10SEG.tif',
#  'fia/hls_output_2021-05-13/2018_10SEH.tif',
#  'fia/hls_output_2021-05-13/2018_10SEJ.tif',
#  'fia/hls_output_2021-05-13/2018_10SFE.tif',
#  'fia/hls_output_2021-05-13/2018_10SFF.tif',
#  'fia/hls_output_2021-05-13/2018_10SFG.tif',
#  'fia/hls_output_2021-05-13/2018_10SFH.tif',
#  'fia/hls_output_2021-05-13/2018_10SFJ.tif',
#  'fia/hls_output_2021-05-13/2018_10SGD.tif',
#  'fia/hls_output_2021-05-13/2018_10SGE.tif',
#  'fia/hls_output_2021-05-13/2018_10SGF.tif',
#  'fia/hls_output_2021-05-13/2018_10SGG.tif',
#  'fia/hls_output_2021-05-13/2018_10SGH.tif',
#  'fia/hls_output_2021-05-13/2018_10SGJ.tif',
#  'fia/hls_output_2021-05-13/2018_10TCK.tif',
#  'fia/hls_output_2021-05-13/2018_10TCL.tif',
#  'fia/hls_output_2021-05-13/2018_10TCM.tif',
#  'fia/hls_output_2021-05-13/2018_10TCN.tif',
#  'fia/hls_output_2021-05-13/2018_10TCP.tif',
#  'fia/hls_output_2021-05-13/2018_10TCT.tif',
#  'fia/hls_output_2021-05-13/2018_10TDK.tif',
#  'fia/hls_output_2021-05-13/2018_10TDL.tif',
#  'fia/hls_output_2021-05-13/2018_10TDM.tif',
#  'fia/hls_output_2021-05-13/2018_10TDN.tif',
#  'fia/hls_output_2021-05-13/2018_10TDP.tif',
#  'fia/hls_output_2021-05-13/2018_10TDQ.tif',
#  'fia/hls_output_2021-05-13/2018_10TDR.tif',
#  'fia/hls_output_2021-05-13/2018_10TDS.tif',
#  'fia/hls_output_2021-05-13/2018_10TDT.tif',
#  'fia/hls_output_2021-05-13/2018_10TEK.tif',
#  'fia/hls_output_2021-05-13/2018_10TEL.tif',
#  'fia/hls_output_2021-05-13/2018_10TEM.tif',
#  'fia/hls_output_2021-05-13/2018_10TEN.tif',
#  'fia/hls_output_2021-05-13/2018_10TEP.tif',
#  'fia/hls_output_2021-05-13/2018_10TEQ.tif',
#  'fia/hls_output_2021-05-13/2018_10TER.tif',
#  'fia/hls_output_2021-05-13/2018_10TES.tif',
#  'fia/hls_output_2021-05-13/2018_10TET.tif',
#  'fia/hls_output_2021-05-13/2018_10TFK.tif',
#  'fia/hls_output_2021-05-13/2018_10TFL.tif',
#  'fia/hls_output_2021-05-13/2018_10TFM.tif',
#  'fia/hls_output_2021-05-13/2018_10TFN.tif',
#  'fia/hls_output_2021-05-13/2018_10TFP.tif',
#  'fia/hls_output_2021-05-13/2018_10TFQ.tif',
#  'fia/hls_output_2021-05-13/2018_10TFR.tif',
#  'fia/hls_output_2021-05-13/2018_10TFS.tif',
#  'fia/hls_output_2021-05-13/2018_10TFT.tif',
#  'fia/hls_output_2021-05-13/2018_10TGK.tif',
#  'fia/hls_output_2021-05-13/2018_10TGL.tif',
#  'fia/hls_output_2021-05-13/2018_10TGM.tif',
#  'fia/hls_output_2021-05-13/2018_10TGN.tif',
#  'fia/hls_output_2021-05-13/2018_10TGT.tif',
#  'fia/hls_output_2021-05-13/2018_10UCU.tif',
#  'fia/hls_output_2021-05-13/2018_10UDU.tif',
#  'fia/hls_output_2021-05-13/2018_10UDV.tif',
#  'fia/hls_output_2021-05-13/2018_10UEU.tif',
#  'fia/hls_output_2021-05-13/2018_10UEV.tif',
#  'fia/hls_output_2021-05-13/2018_10UFU.tif',
#  'fia/hls_output_2021-05-13/2018_10UFV.tif',
#  'fia/hls_output_2021-05-13/2018_10UGU.tif',
#  'fia/hls_output_2021-05-13/2018_10UGV.tif',
#  'fia/hls_output_2021-05-13/2018_11SKA.tif',
#  'fia/hls_output_2021-05-13/2018_11SKB.tif',
#  'fia/hls_output_2021-05-13/2018_11SKC.tif',
#  'fia/hls_output_2021-05-13/2018_11SKD.tif',
#  'fia/hls_output_2021-05-13/2018_11SKT.tif',
#  'fia/hls_output_2021-05-13/2018_11SKU.tif',
#  'fia/hls_output_2021-05-13/2018_11SKV.tif',
#  'fia/hls_output_2021-05-13/2018_11SLA.tif',
#  'fia/hls_output_2021-05-13/2018_11SLB.tif',
#  'fia/hls_output_2021-05-13/2018_11SLC.tif',
#  'fia/hls_output_2021-05-13/2018_11SLT.tif',
#  'fia/hls_output_2021-05-13/2018_11SLU.tif',
#  'fia/hls_output_2021-05-13/2018_11SLV.tif',
#  'fia/hls_output_2021-05-13/2018_11SMA.tif',
#  'fia/hls_output_2021-05-13/2018_11SMR.tif',
#  'fia/hls_output_2021-05-13/2018_11SMS.tif',
#  'fia/hls_output_2021-05-13/2018_11SMT.tif',
#  'fia/hls_output_2021-05-13/2018_11SMU.tif',
#  'fia/hls_output_2021-05-13/2018_11SMV.tif',
#  'fia/hls_output_2021-05-13/2018_11SNS.tif',
#  'fia/hls_output_2021-05-13/2018_11SNT.tif',
#  'fia/hls_output_2021-05-13/2018_11SNU.tif',
#  'fia/hls_output_2021-05-13/2018_11SPS.tif',
#  'fia/hls_output_2021-05-13/2018_11TKE.tif',
#  'fia/hls_output_2021-05-13/2018_11TKF.tif',
#  'fia/hls_output_2021-05-13/2018_11TKG.tif',
#  'fia/hls_output_2021-05-13/2018_11ULP.tif',
#  'fia/hls_output_2021-05-13/2018_11ULQ.tif']

# %% [markdown]
# ### Choose a region and time of interest
#
# Choose a test area from the USGS data, we will repeat later for Brazil
# but deciding our range around the station is important and should be discussed with the team

# %%
import pandas as pd
import fsspec
import numpy as np
import geopandas as gpd
import rasterio
from rasterio import windows
from rasterio import features
from rasterio import warp

from PIL import Image
import matplotlib.pyplot as plt

container = 'usgs-data'

storage_options={'account_name':os.environ['ACCOUNT_NAME'],\
                 'account_key':os.environ['BLOB_KEY']}
fs = fsspec.filesystem('az', account_name=storage_options['account_name'], account_key=storage_options['account_key'])
station_url = f'az://{container}/station_metadata.csv'
station_df = pd.read_csv(station_url, storage_options=storage_options)                
fs_list = fs.ls('usgs-data/stations')
station_list = pd.DataFrame({'site_no':filter(None,\
                           map(lambda sub:(''.join([ele for ele in sub if ele.isnumeric()])), fs_list))}).astype('int')
filtered_station_df = station_list.merge(station_df, on='site_no')
#filter the stations to ones with data

crs = {'init': 'epsg:4326'}
gdf = gpd.GeoDataFrame(filtered_station_df,\
                       geometry=gpd.points_from_xy(filtered_station_df.Longitude, filtered_station_df.Latitude))
buffer_style = {'round':1,'flat':2,'square':3}
buffer = 0.005
gdf.geometry = gdf.geometry.buffer(buffer, cap_style = buffer_style['square'], resolution=1)

gdf = gdf.drop_duplicates()

# %%
def get_spacetime_bounds(station):
    coordinates =  np.dstack(station.geometry.boundary.coords.xy).tolist()
    area_of_interest = {
        "type": "Polygon",
        "coordinates": coordinates,
    }
    start = df['Date-Time'].iloc[0].strftime('%Y-%m-%d')
    end = df['Date-Time'].iloc[-1].strftime('%Y-%m-%d')
    #use the date range of the data?
    #time_of_interest = "2019-06-01/2019-08-01"
    time_of_interest = f'{start}/{end}'
    return area_of_interest, time_of_interest

def build_catalog(area_of_interest, time_of_interest,collection='sentinel-2-l2a'):
    ''' 
    Use pystac-client to search for Sentinel 2 L2A data
    '''
    catalog = Client.open("https://planetarycomputer.microsoft.com/api/stac/v1")

    search = catalog.search(
        collections=[collection], 
        intersects=area_of_interest, 
        datetime=time_of_interest    
    )
    print(f"{search.matched()} Items found")
    return search

def get_scl_chip(signed_url, area_of_interest, write_to_filename=None):
    with rasterio.open(signed_url) as ds:    
        aoi_bounds = features.bounds(area_of_interest)
        warped_aoi_bounds = warp.transform_bounds('epsg:4326', ds.crs, *aoi_bounds)
        aoi_window = windows.from_bounds(transform=ds.transform, *warped_aoi_bounds)
        band_data = ds.read(window=aoi_window)
        scl = band_data[0].repeat(2, axis=0).repeat(2, axis=1)
        return scl
    
def get_visual_chip(signed_url, area_of_interest, write_to_filename=None):
    with rasterio.open(signed_url) as ds:    
        aoi_bounds = features.bounds(area_of_interest)
        warped_aoi_bounds = warp.transform_bounds('epsg:4326', ds.crs, *aoi_bounds)
        aoi_window = windows.from_bounds(transform=ds.transform, *warped_aoi_bounds)
        band_data = ds.read(window=aoi_window)
        img = Image.fromarray(np.transpose(band_data, axes=[1, 2, 0]))
        #w = img.size[0]; h = img.size[1]; aspect = w/h
        #target_w = scl.shape[1]; target_h = scl.shape[0]
        #img = img.resize((target_w,target_h),Image.BILINEAR)
        return img
    
def get_filtered_cloud_list(search, cloud_thr):
    scene_list = sorted(search.items(), key=lambda item: item.ext.eo.cloud_cover)
    cloud_list = pd.DataFrame([{'Date-Time':s.datetime.strftime('%Y-%m-%d'),\
                            'Cloud Cover':s.ext.eo.cloud_cover,\
                            'visual-href':s.assets['visual-10m'].href,\
                            'scl-href':s.assets['SCL-20m'].href} for s in scene_list if s.ext.eo.cloud_cover<cloud_thr])
    cloud_list['Date-Time'] = pd.to_datetime(cloud_list['Date-Time'])
    return cloud_list

def chip_cloud_analysis(scl):
    n_total_pxls = np.multiply(scl.shape[0], scl.shape[1])
    n_cloud_pxls = np.sum((scl>=7) & (scl<=10))
    chip_cloud_pct = 100*(n_cloud_pxls/n_total_pxls)
    return chip_cloud_pct

# %%
#iterate here for writing the data
for i, station in gdf[21:22].iterrows():
    url = f'az://{container}/stations/{str(station.site_no).zfill(8)}_data.csv' #zero pad 8 digits for site_no
    df = pd.read_csv(url, storage_options=storage_options) 
    df['Date-Time'] = pd.to_datetime(df['Date-Time'])
    df = df.sort_values(by='Date-Time')
    #Define the aoi and time range to filter images with. 
    area_of_interest, time_of_interest = get_spacetime_bounds(station)
    search = build_catalog(area_of_interest, time_of_interest)
    cloud_thr = 100 #set threshold high
    cloud_list = get_filtered_cloud_list(search, cloud_thr)
    #merge with the df
    df = df.merge(cloud_list, on='Date-Time')
    #get the scence list dates and the cloud cover
    chip_clouds = [chip_cloud_analysis(get_scl_chip(pc.sign(sc['scl-href']),area_of_interest)) for i, sc in df.iterrows()]

    #write the completed database with chip clouds and file names into '/blob/stations/{site_no}/{site_no}.csv'
    #afterwards write a summary into the metadata
    df['Chip Cloud Pct']  = chip_clouds
    #write everything out
    site = str(station['site_no']).zfill(8)
    write_url = f'az://{container}/stations/{site}/{site}.csv'
    #df.to_csv(write_url, storage_options=storage_options)
# Out:
# 42 Items found

# %%
df
# Out:
#     Date-Time  Instantaneous computed discharge (cfs)  \
# 0  2015-10-01                                    2760
# 1  2015-10-01                                    2760
# 2  2015-10-21                                    1220
# 3  2015-10-21                                    1220
# 4  2016-03-29                                    3920
# 5  2016-04-15                                    2270
# 6  2016-04-15                                    2270
# 7  2016-04-28                                   12900
# 8  2016-04-28                                   12900
# 9  2016-05-05                                   12600
# 10 2016-05-05                                   12600
# 11 2016-05-18                                    6050
# 12 2016-05-18                                    6050
# 13 2016-05-25                                    6330
# 14 2016-05-25                                    6330
# 15 2016-06-07                                    3860
# 16 2016-06-07                                    3860
# 17 2016-06-14                                    3060
# 18 2016-06-14                                    3060
# 19 2016-06-27                                    3300
# 20 2016-06-27                                    3300
# 21 2016-07-17                                    2270
# 22 2016-07-17                                    2270
# 23 2016-08-06                                    1690
# 24 2016-08-06                                    1690
# 25 2016-08-13                                    1420
# 26 2016-08-13                                    1420
# 27 2016-08-26                                    3080
# 28 2016-08-26                                    3080
# 29 2016-09-02                                    1590
# 30 2016-09-02                                    1590
# 31 2016-09-15                                    1810
# 32 2016-09-15                                    1810
# 33 2016-09-22                                    1960
# 34 2016-09-22                                    1960
# 35 2016-10-05                                    1560
# 36 2016-10-05                                    1560
#
#     Computed instantaneous suspended sediment (mg/L)  \
# 0                                                650
# 1                                                650
# 2                                                230
# 3                                                230
# 4                                                460
# 5                                                240
# 6                                                240
# 7                                               2100
# 8                                               2100
# 9                                               1500
# 10                                              1500
# 11                                               720
# 12                                               720
# 13                                               650
# 14                                               650
# 15                                               510
# 16                                               510
# 17                                               470
# 18                                               470
# 19                                               510
# 20                                               510
# 21                                               440
# 22                                               440
# 23                                               470
# 24                                               470
# 25                                               320
# 26                                               320
# 27                                               970
# 28                                               970
# 29                                               680
# 30                                               680
# 31                                               720
# 32                                               720
# 33                                               540
# 34                                               540
# 35                                               290
# 36                                               290
#
#     Computed instantaneous suspended sediment, lower 90% prediction (mg/L)  \
# 0                                                 320
# 1                                                 320
# 2                                                 110
# 3                                                 110
# 4                                                 230
# 5                                                 120
# 6                                                 120
# 7                                                1000
# 8                                                1000
# 9                                                 730
# 10                                                730
# 11                                                360
# 12                                                360
# 13                                                320
# 14                                                320
# 15                                                250
# 16                                                250
# 17                                                230
# 18                                                230
# 19                                                250
# 20                                                250
# 21                                                220
# 22                                                220
# 23                                                230
# 24                                                230
# 25                                                160
# 26                                                160
# 27                                                490
# 28                                                490
# 29                                                340
# 30                                                340
# 31                                                360
# 32                                                360
# 33                                                270
# 34                                                270
# 35                                                140
# 36                                                140
#
#     Computed instantaneous suspended sediment, upper 90% prediction (mg/L)  \
# 0                                                1300
# 1                                                1300
# 2                                                 460
# 3                                                 460
# 4                                                 930
# 5                                                 490
# 6                                                 490
# 7                                                4200
# 8                                                4200
# 9                                                3000
# 10                                               3000
# 11                                               1400
# 12                                               1400
# 13                                               1300
# 14                                               1300
# 15                                               1000
# 16                                               1000
# 17                                                940
# 18                                                940
# 19                                               1000
# 20                                               1000
# 21                                                880
# 22                                                880
# 23                                                940
# 24                                                940
# 25                                                660
# 26                                                660
# 27                                               2000
# 28                                               2000
# 29                                               1400
# 30                                               1400
# 31                                               1400
# 32                                               1400
# 33                                               1100
# 34                                               1100
# 35                                                580
# 36                                                580
#
#     Instantaneous turbidity (FNU)  Cloud Cover  \
# 0                             150    50.373503
# 1                             150    54.679705
# 2                              40    83.369845
# 3                              40    84.945726
# 4                              98    99.999985
# 5                              43    96.161142
# 6                              43    97.141206
# 7                             640    99.996699
# 8                             640    99.997801
# 9                             420     0.464793
# 10                            420     0.553027
# 11                            170    31.557584
# 12                            170    31.641314
# 13                            150    21.064347
# 14                            150    24.823736
# 15                            110     0.177635
# 16                            110     0.200370
# 17                            100    72.328662
# 18                            100    72.748554
# 19                            110    27.045677
# 20                            110    29.232217
# 21                             92    73.086364
# 22                             92    75.168239
# 23                            100    77.551011
# 24                            100    80.622820
# 25                             63     0.373970
# 26                             63     0.395871
# 27                            250    96.820452
# 28                            250    98.999288
# 29                            160    34.101282
# 30                            160    35.685353
# 31                            170    87.431236
# 32                            170    87.438883
# 33                            120    25.661565
# 34                            120    26.002979
# 35                             54     2.332418
# 36                             54     2.513675
#
#                                           visual-href  \
# 0   https://sentinel2l2a01.blob.core.windows.net/s...
# 1   https://sentinel2l2a01.blob.core.windows.net/s...
# 2   https://sentinel2l2a01.blob.core.windows.net/s...
# 3   https://sentinel2l2a01.blob.core.windows.net/s...
# 4   https://sentinel2l2a01.blob.core.windows.net/s...
# 5   https://sentinel2l2a01.blob.core.windows.net/s...
# 6   https://sentinel2l2a01.blob.core.windows.net/s...
# 7   https://sentinel2l2a01.blob.core.windows.net/s...
# 8   https://sentinel2l2a01.blob.core.windows.net/s...
# 9   https://sentinel2l2a01.blob.core.windows.net/s...
# 10  https://sentinel2l2a01.blob.core.windows.net/s...
# 11  https://sentinel2l2a01.blob.core.windows.net/s...
# 12  https://sentinel2l2a01.blob.core.windows.net/s...
# 13  https://sentinel2l2a01.blob.core.windows.net/s...
# 14  https://sentinel2l2a01.blob.core.windows.net/s...
# 15  https://sentinel2l2a01.blob.core.windows.net/s...
# 16  https://sentinel2l2a01.blob.core.windows.net/s...
# 17  https://sentinel2l2a01.blob.core.windows.net/s...
# 18  https://sentinel2l2a01.blob.core.windows.net/s...
# 19  https://sentinel2l2a01.blob.core.windows.net/s...
# 20  https://sentinel2l2a01.blob.core.windows.net/s...
# 21  https://sentinel2l2a01.blob.core.windows.net/s...
# 22  https://sentinel2l2a01.blob.core.windows.net/s...
# 23  https://sentinel2l2a01.blob.core.windows.net/s...
# 24  https://sentinel2l2a01.blob.core.windows.net/s...
# 25  https://sentinel2l2a01.blob.core.windows.net/s...
# 26  https://sentinel2l2a01.blob.core.windows.net/s...
# 27  https://sentinel2l2a01.blob.core.windows.net/s...
# 28  https://sentinel2l2a01.blob.core.windows.net/s...
# 29  https://sentinel2l2a01.blob.core.windows.net/s...
# 30  https://sentinel2l2a01.blob.core.windows.net/s...
# 31  https://sentinel2l2a01.blob.core.windows.net/s...
# 32  https://sentinel2l2a01.blob.core.windows.net/s...
# 33  https://sentinel2l2a01.blob.core.windows.net/s...
# 34  https://sentinel2l2a01.blob.core.windows.net/s...
# 35  https://sentinel2l2a01.blob.core.windows.net/s...
# 36  https://sentinel2l2a01.blob.core.windows.net/s...
#
#                                              scl-href  Chip Cloud Pct
# 0   https://sentinel2l2a01.blob.core.windows.net/s...       51.245847
# 1   https://sentinel2l2a01.blob.core.windows.net/s...       50.550796
# 2   https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 3   https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 4   https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 5   https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 6   https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 7   https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 8   https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 9   https://sentinel2l2a01.blob.core.windows.net/s...        7.848837
# 10  https://sentinel2l2a01.blob.core.windows.net/s...        8.649531
# 11  https://sentinel2l2a01.blob.core.windows.net/s...       81.925745
# 12  https://sentinel2l2a01.blob.core.windows.net/s...       81.187708
# 13  https://sentinel2l2a01.blob.core.windows.net/s...        4.651163
# 14  https://sentinel2l2a01.blob.core.windows.net/s...        5.303958
# 15  https://sentinel2l2a01.blob.core.windows.net/s...        2.408638
# 16  https://sentinel2l2a01.blob.core.windows.net/s...        2.121583
# 17  https://sentinel2l2a01.blob.core.windows.net/s...       28.314973
# 18  https://sentinel2l2a01.blob.core.windows.net/s...       28.322259
# 19  https://sentinel2l2a01.blob.core.windows.net/s...        2.121583
# 20  https://sentinel2l2a01.blob.core.windows.net/s...        1.702658
# 21  https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 22  https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 23  https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 24  https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 25  https://sentinel2l2a01.blob.core.windows.net/s...        3.590371
# 26  https://sentinel2l2a01.blob.core.windows.net/s...        3.612957
# 27  https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 28  https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 29  https://sentinel2l2a01.blob.core.windows.net/s...       42.691030
# 30  https://sentinel2l2a01.blob.core.windows.net/s...       44.390045
# 31  https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 32  https://sentinel2l2a01.blob.core.windows.net/s...      100.000000
# 33  https://sentinel2l2a01.blob.core.windows.net/s...        3.590371
# 34  https://sentinel2l2a01.blob.core.windows.net/s...        3.446844
# 35  https://sentinel2l2a01.blob.core.windows.net/s...        3.182375
# 36  https://sentinel2l2a01.blob.core.windows.net/s...        2.990033

# %% [markdown]
# ## classification {labels 8: 'CLOUD_MEDIUM_PROBABILITY', 9:'CLOUD_HIGH_PROBABILITY', 10:'THIN_CIRRUS', 11:'SNOW'}

# %%
scene_query = df.iloc[9] #here we are testing for a cloud threshold
#loop here
visual_href = pc.sign(scene_query['visual-href'])
scl_href = pc.sign(scene_query['scl-href'])

# %% [markdown]
# We can now use the HREF to read our data in any tools that can retrieve data from URLs via HTTP GET operations.
#
# For example, here we use rasterio to render the image data over our area of interest:
#
# ## 0.1.4. Render our AOI from this image

# %%
f, ax = plt.subplots(1,1,figsize=(20,8))
ax.scatter(df['Cloud Cover'],df['Chip Cloud Pct'])
ax.set_xlabel('cloud cover')
ax.set_ylabel('pixels cloud cover')
# Out:
# Text(0, 0.5, 'pixels cloud cover')

# %% [markdown]
# Get the URL to the 10m resolution visual [Cloud Optimized GeoTIFF](https://www.cogeo.org/) image.
#
# This HREF is a URL is the location of the asset data on Azure Blob Storage. In order to read the data, we'll need to retrieve a Shared Access Signature and supply it as a query parameter. These tokens are generated from the Planetary Computer Data Access API.
#
# We use the planetary-computer package to "sign" our asset HREF with a generated token:

# %%
for i, station in gdf.iterrows():
    site = str(station.site_no).zfill(8)
    url = f'az://{container}/stations/{site}/{site}.csv'
    print(url)
    df = pd.read_csv(url, storage_options=storage_options) 
    df['Date-Time'] = pd.to_datetime(df['Date-Time'])
    df = df.sort_values(by='Date-Time')
    #Define the aoi and time range to filter images with. 
    area_of_interest, time_of_interest = get_spacetime_bounds(station)
    search = build_catalog(area_of_interest, time_of_interest)
    scene_query = df.iloc[1] #here we are testing for a cloud threshold
    #loop here
    visual_href = pc.sign(scene_query['visual-href'])
    scl_href = pc.sign(scene_query['scl-href'])
# Out:
# az://usgs-data/stations/06818000/06818000.csv
# 84 Items found

# %%
with rasterio.open(scl_href) as ds:    
    aoi_bounds = features.bounds(area_of_interest)
    warped_aoi_bounds = warp.transform_bounds('epsg:4326', ds.crs, *aoi_bounds)
    aoi_window = windows.from_bounds(transform=ds.transform, *warped_aoi_bounds)
    band_data = ds.read(window=aoi_window)
    scl = band_data[0].repeat(2, axis=0).repeat(2, axis=1)

with rasterio.open(visual_href) as ds:    
    aoi_bounds = featureS.bounds(area_of_interest)
    warped_aoi_bounds = warp.transform_bounds('epsg:4326', ds.crs, *aoi_bounds)
    aoi_window = windows.from_bounds(transform=ds.transform, *warped_aoi_bounds)
    band_data = ds.read(window=aoi_window)
    img = Image.fromarray(np.transpose(band_data, axes=[1, 2, 0]))
    w = img.size[0]; h = img.size[1]; aspect = w/h
    #target_w = img.size[0]*2; target_h = (int)(target_w/aspect)
    target_w = scl.shape[1]; target_h = scl.shape[0]
    img = img.resize((target_w,target_h),Image.BILINEAR)
    

f, ax = plt.subplots(1,4, figsize=(20,20))
cloud_mask = scl>7
water_mask = (scl==6)
ax[0].imshow(img)
ax[1].imshow(scl, cmap='Accent')
ax[2].imshow(cloud_mask)
ax[3].imshow(water_mask, cmap='Blues')
    #we can download the image chips here and place them in the usgs-data/{site_no}/

# %%
np.mean(np.array(img)[water_mask], axis=0)
# Out:
# array([95.30862647, 99.33919598, 79.34924623])

# %%
a = rasterio.open(visual_href).read()

# %%
a.shape
# Out:
# (3, 10980, 10980)

# %%
a.size *a.itemsize * 1e-6
# Out:
# 361.6812

# %% [markdown]
# ### all bands require 120.5604 mb
# sentinel 2 has b2, b3, b4, and b8 as 10m resolution and classification at 20m which is (1, 5490, 5490) requires only 30.1401 mb

# %% [markdown]
# rasterio gives us data band-interleave format; transpose to pixel interleave, and downscale the image data for plotting. Given the bounds, we will select the a nxn image around our point of interest

# %% [markdown]
# We might be able to create a small semantic segmentation model using our classification layer and then run that first on a scene from landsat...

# %%
f, ax = plt.subplots(1,1, figsize=(20,20))
mask = water_mask[..., np.newaxis] * np.ones(np.array(img).shape).astype('bool')
#water = np.ma.MaskedArray(np.array(img), mask=~mask)
water = np.array(img)
water[~mask] =255 
ax.imshow(water)

# %%
from scipy import ndimage
from skimage import filters
from skimage import restoration
f, ax = plt.subplots(1,1, figsize=(20,20))
#filt = restoration.denoise_tv_chambolle(mask,weight=1.8)
filt = ndimage.binary_erosion(mask[...,0], structure=np.ones((3,3)))
filt = ndimage.median_filter(filt, 9)
ax.imshow(filt)

# %%
#we might add a line to the gdf to include total number of cloud free chips?
#task is to open each site_no and the get the df of the estimates and then look at the cloud cover average
date_range_list = []
cloudless_count_list = []
site_no_list = []
for i, station in gdf.iterrows():
    site = str(station.site_no).zfill(8)
    url = f'az://{container}/stations/{site}/{site}.csv' #zero pad 8 digits for site_no
    try:
        df = pd.read_csv(url, storage_options=storage_options) 
        df['Date-Time'] = pd.to_datetime(df['Date-Time'])
        df = df.sort_values(by='Date-Time')
        if len(df)>0:
            #Define the aoi and time range to filter images with. 
            area_of_interest, time_of_interest = get_spacetime_bounds(station)
            cloud_thr = 5
            cloud_chip_count = len(df[df['Chip Cloud Pct']<cloud_thr])
            cloudless_count_list.append(cloud_chip_count)
            date_range_list.append(time_of_interest)
            site_no_list.append(int(site))
    except:
        print(f'{url} does not exist')
    
meta = pd.DataFrame({'site_no':site_no_list, 'cloudless_img_count':cloudless_count_list, 'date_range':date_range_list})
station_url = f'az://{container}/station_img_metadata.csv'
gdf.merge(meta, on='site_no').to_csv(station_url, storage_options=storage_options, index=False )
# Out:
# az://usgs-data/stations/06893390/06893390.csv does not exist
